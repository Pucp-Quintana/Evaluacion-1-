# %%
#Links de las datas
#Emisiones de (CO2) = https://edgar.jrc.ec.europa.eu/report_2022#emissions_table
#Temperatura mundial = https://climatedata.imf.org/pages/climatechange-data
#Tasa de mortalidad materna = https://datos.bancomundial.org/indicador/SH.STA.MMRT

# %%
#1 Subir la data y limpiar
#Emisiones de CO2
from IPython.display import IFrame  
emisiones= "https://edgar.jrc.ec.europa.eu/report_2022#emissions_table"

# %%
 import pandas as pd

emsions=pd.read_html(emisiones, # link
                        header=0, # where is the header?
                        flavor='bs4')
emisions
# Out:
#    Gas emissions in MtCO₂                                         Unnamed: 1  \
# 0                     NaN                                        Afghanistan
# 1                    1960                                                  0
# 2                    1961                                                  0
# 3                    1962                                                  0
# 4                    1963                                                  0
# ..                    ...                                                ...
# 61                   2020                                            0.25124
# 62                   2021                                            0.23885
# 63                    NaN                                                NaN
# 64                SOURCES                                                NaN
# 65                    Gas  <b>For sources and methods, see Friedlingstein...
#
# ...

# %%
emisions.columns
# Out:
# Index(['Gas emissions in MtCO₂', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9',
#        ...
#        'Unnamed: 212', 'Unnamed: 213', 'Unnamed: 214', 'Unnamed: 215',
#        'Unnamed: 216', 'Unnamed: 217', 'Unnamed: 218', 'Unnamed: 219',
#        'Unnamed: 220', 'Unnamed: 221'],
#       dtype='object', length=222)

# %%
type(emisions)
# Out:
# pandas.core.frame.DataFrame

# %%
emisions1 = emisions.transpose() 
emisions1
# Out:
#                                                0         1         2   \
# Gas emissions in MtCO₂                        NaN      1960      1961
# Unnamed: 1                            Afghanistan         0         0
# Unnamed: 2                                Albania  0.084272  0.084137
# Unnamed: 3                                Algeria         0    0.4504
# Unnamed: 4                                Andorra       NaN       NaN
# ...                                           ...       ...       ...
# Unnamed: 217            Wallis and Futuna Islands       NaN       NaN
# Unnamed: 218                       Western Sahara       NaN       NaN
# Unnamed: 219                                Yemen         0         0
# Unnamed: 220                               Zambia         0         0
# Unnamed: 221                             Zimbabwe         0         0
#
#                               3         4         5        6        7   \
# ...

# %%
emisions1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222 entries, Gas emissions in MtCO₂ to Unnamed: 221
# Data columns (total 66 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       221 non-null    object
#  1   1       189 non-null    object
#  2   2       190 non-null    object
#  3   3       192 non-null    object
#  4   4       193 non-null    object
#  5   5       196 non-null    object
#  6   6       196 non-null    object
#  7   7       196 non-null    object
#  8   8       196 non-null    object
#  9   9       197 non-null    object
#  10  10      197 non-null    object
#  11  11      199 non-null    object
#  12  12      200 non-null    object
#  13  13      201 non-null    object
#  14  14      201 non-null    object
#  15  15      201 non-null    object
#  16  16      201 non-null    object
#  17  17      201 non-null    object
#  18  18      201 non-null    object
#  19  19      201 non-null    object
# ...

# %%
#Utiice  str.replace para cambiar la , a . 
emisions2 = emisions1.apply(lambda x: x.str.replace(',', '.', regex=True))
emisions2
# Out:
#                                                0         1         2   \
# Gas emissions in MtCO₂                        NaN      1960      1961
# Unnamed: 1                            Afghanistan         0         0
# Unnamed: 2                                Albania  0.084272  0.084137
# Unnamed: 3                                Algeria         0    0.4504
# Unnamed: 4                                Andorra       NaN       NaN
# ...                                           ...       ...       ...
# Unnamed: 217            Wallis and Futuna Islands       NaN       NaN
# Unnamed: 218                       Western Sahara       NaN       NaN
# Unnamed: 219                                Yemen         0         0
# Unnamed: 220                               Zambia         0         0
# Unnamed: 221                             Zimbabwe         0         0
#
#                               3         4         5        6        7   \
# ...

# %%
#Utilice la funcion de strip() y .applymap() para eliminar los espacios en blanco de los costados
emisions3 = emisions2.applymap(lambda x: x.strip() if isinstance(x, str) else x)
emisions3
# Out:
#                                                0         1         2   \
# Gas emissions in MtCO₂                        NaN      1960      1961
# Unnamed: 1                            Afghanistan         0         0
# Unnamed: 2                                Albania  0.084272  0.084137
# Unnamed: 3                                Algeria         0    0.4504
# Unnamed: 4                                Andorra       NaN       NaN
# ...                                           ...       ...       ...
# Unnamed: 217            Wallis and Futuna Islands       NaN       NaN
# Unnamed: 218                       Western Sahara       NaN       NaN
# Unnamed: 219                                Yemen         0         0
# Unnamed: 220                               Zambia         0         0
# Unnamed: 221                             Zimbabwe         0         0
#
#                               3         4         5        6        7   \
# ...

# %%
emisions4 = emisions3.applymap(lambda x: x.strip() if isinstance(x, str) else x)
emisions4
# Out:
#                                                0         1         2   \
# Gas emissions in MtCO₂                        NaN      1960      1961
# Unnamed: 1                            Afghanistan         0         0
# Unnamed: 2                                Albania  0.084272  0.084137
# Unnamed: 3                                Algeria         0    0.4504
# Unnamed: 4                                Andorra       NaN       NaN
# ...                                           ...       ...       ...
# Unnamed: 217            Wallis and Futuna Islands       NaN       NaN
# Unnamed: 218                       Western Sahara       NaN       NaN
# Unnamed: 219                                Yemen         0         0
# Unnamed: 220                               Zambia         0         0
# Unnamed: 221                             Zimbabwe         0         0
#
#                               3         4         5        6        7   \
# ...

# %%
#Usamos la funcion .replace para eliminar los espacios en blanco 
emisions5 = emisions4.replace(r'\s+', '', regex=True)
emisions5
# Out:
#                                             0         1         2         3   \
# Gas emissions in MtCO₂                     NaN      1960      1961      1962
# Unnamed: 1                         Afghanistan         0         0         0
# Unnamed: 2                             Albania  0.084272  0.084137  0.084272
# Unnamed: 3                             Algeria         0    0.4504   0.68839
# Unnamed: 4                             Andorra       NaN       NaN       NaN
# ...                                        ...       ...       ...       ...
# Unnamed: 217            WallisandFutunaIslands       NaN       NaN       NaN
# Unnamed: 218                     WesternSahara       NaN       NaN       NaN
# Unnamed: 219                             Yemen         0         0         0
# Unnamed: 220                            Zambia         0         0         0
# Unnamed: 221                          Zimbabwe         0         0         0
#
# ...

# %%
#Como nos sale NAN y 0 lo pasaremos a numero para corregir este error
# Out:
#                                             0            1            2   \
# Gas emissions in MtCO₂                     NaN  1960.000000  1961.000000
# Unnamed: 1                         Afghanistan     0.000000     0.000000
# Unnamed: 2                             Albania     0.084272     0.084137
# Unnamed: 3                             Algeria     0.000000     0.450400
# Unnamed: 4                             Andorra          NaN          NaN
# ...                                        ...          ...          ...
# Unnamed: 217            WallisandFutunaIslands          NaN          NaN
# Unnamed: 218                     WesternSahara          NaN          NaN
# Unnamed: 219                             Yemen     0.000000     0.000000
# Unnamed: 220                            Zambia     0.000000     0.000000
# Unnamed: 221                          Zimbabwe     0.000000     0.000000
#
#                                  3            4            5           6   \
# ...

# %%
emisions5.dtypes
# Out:
# 0      object
# 1      object
# 2      object
# 3      object
# 4      object
#        ...
# 61     object
# 62     object
# 63    float64
# 64     object
# 65     object
# Length: 66, dtype: object
